# %%
# %pylab nbagg
from tvb.simulator.lab import *
import sim
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
epileptic = [9,47]
almost_epileptic = [2,40]
stimulus_target = [9,47,2,40]
stimulus_amplitude = 20
stimulus_weight = 2 #0-2 for each region
onset = 2500
period = 500
pulse_width = 0
sim_time = 500

s = sim.set_sim(epileptic, almost_epileptic, stimulus_target, stimulus_amplitude, 
              stimulus_weight, onset, period, pulse_width, sim_time)
# Out:
# WARNING  File 'hemispheres' not found in ZIP.

# %%
(tt, ta), (teeg, eeg), (st, se) = s.run()

# %%
sim.normalize_plot_tavg(tt, ta, [0,1,38,39, 9,47,2,40], "testing", epileptic, almost_epileptic, 
                    stimulus_target, stimulus_amplitude, stimulus_weight,
                    onset, period, pulse_width)
# Out:
# WARNING  File 'hemispheres' not found in ZIP.
# <img src="data:image/png;base64,...">

# %%
sim.normalize_plot_tavg
# Out:
# <function sim.normalize_plot_tavg>
