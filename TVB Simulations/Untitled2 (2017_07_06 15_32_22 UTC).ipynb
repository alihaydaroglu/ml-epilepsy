# %%
# %pylab nbagg
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
bar([0,1], [2,3])
xticks([0.4,1.4],["a", "b"])
# Out:
# <img src="data:image/png;base64,...">
# ([<matplotlib.axis.XTick at 0x8725898>, <matplotlib.axis.XTick at 0x87f6128>],
#  <a list of 2 Text xticklabel objects>)
